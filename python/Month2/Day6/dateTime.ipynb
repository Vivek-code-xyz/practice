# %%
import pandas as pd
import numpy as np

# %%
pd.Timestamp('2026/3/9')
# Out:
# Timestamp('2026-03-09 00:00:00')

# %%
pd.Timestamp('2026-5-3')
# Out:
# Timestamp('2026-05-03 00:00:00')

# %%
x =pd.Timestamp('5th january 2026 9:48AM')

# %%
x.month
# Out:
# 1

# %%
x.year
# Out:
# 2026

# %%
#dateTimeIndex
pd.DatetimeIndex(['2024/5/3','2025/3/4','2024/6/4'])[0]
# Out:
# Timestamp('2024-05-03 00:00:00')

# %%
#datereangeFunc
pd.date_range(start='2024/5/7' , end='2024/8/9',freq='B')
# Out:
# DatetimeIndex(['2024-05-07', '2024-05-08', '2024-05-09', '2024-05-10',
#                '2024-05-13', '2024-05-14', '2024-05-15', '2024-05-16',
#                '2024-05-17', '2024-05-20', '2024-05-21', '2024-05-22',
#                '2024-05-23', '2024-05-24', '2024-05-27', '2024-05-28',
#                '2024-05-29', '2024-05-30', '2024-05-31', '2024-06-03',
#                '2024-06-04', '2024-06-05', '2024-06-06', '2024-06-07',
#                '2024-06-10', '2024-06-11', '2024-06-12', '2024-06-13',
#                '2024-06-14', '2024-06-17', '2024-06-18', '2024-06-19',
#                '2024-06-20', '2024-06-21', '2024-06-24', '2024-06-25',
#                '2024-06-26', '2024-06-27', '2024-06-28', '2024-07-01',
#                '2024-07-02', '2024-07-03', '2024-07-04', '2024-07-05',
#                '2024-07-08', '2024-07-09', '2024-07-10', '2024-07-11',
#                '2024-07-12', '2024-07-15', '2024-07-16', '2024-07-17',
# ...

# %%
pd.date_range(start='2024/5/7' , periods=56,freq='M')
# Out:
# C:\Users\khasi\AppData\Local\Temp\ipykernel_2000\2806797508.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.date_range(start='2024/5/7' , periods=56,freq='M')
# DatetimeIndex(['2024-05-31', '2024-06-30', '2024-07-31', '2024-08-31',
#                '2024-09-30', '2024-10-31', '2024-11-30', '2024-12-31',
#                '2025-01-31', '2025-02-28', '2025-03-31', '2025-04-30',
#                '2025-05-31', '2025-06-30', '2025-07-31', '2025-08-31',
#                '2025-09-30', '2025-10-31', '2025-11-30', '2025-12-31',
#                '2026-01-31', '2026-02-28', '2026-03-31', '2026-04-30',
#                '2026-05-31', '2026-06-30', '2026-07-31', '2026-08-31',
#                '2026-09-30', '2026-10-31', '2026-11-30', '2026-12-31',
#                '2027-01-31', '2027-02-28', '2027-03-31', '2027-04-30',
#                '2027-05-31', '2027-06-30', '2027-07-31', '2027-08-31',
# ...

# %%
df = pd.read_csv('expense_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    object
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: float64(5), object(6)
# memory usage: 23.9+ KB

# %%
df.Date = pd.to_datetime(df.Date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    datetime64[ns]
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 23.9+ KB

# %%
df.Date.dt.month
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 272    11
# 273    11
# 274    11
# 275    11
# 276    11
# Name: Date, Length: 277, dtype: int32

# %%
import matplotlib.pyplot as plt

# %%
df['DayName'] = df.Date.dt.day_name()

# %%
df.head()
# Out:
#                  Date               Account        Category  Subcategory  \
# 0 2022-03-02 10:11:00  CUB - online payment            Food          NaN
# 1 2022-03-02 10:11:00  CUB - online payment           Other          NaN
# 2 2022-03-01 19:50:00  CUB - online payment            Food          NaN
# 3 2022-03-01 18:56:00  CUB - online payment  Transportation          NaN
# 4 2022-03-01 18:22:00  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1  \
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0
#
#      DayName
# 0  Wednesday
# 1  Wednesday
# 2    Tuesday
# ...

# %%
df.groupby('DayName')['INR'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='DayName'>
