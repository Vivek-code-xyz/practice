# %%
import pandas as pd
import numpy as np

# %%
ipl = pd.read_csv('ipl-matches.csv')
ipl.head(3)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# ...

# %%
#find player of the mathc most for the special mathces
ipl[~ipl['MatchNumber'].str.isdigit()][['Player_of_Match']].value_counts()
# Out:
# Player_of_Match
# F du Plessis         3
# KA Pollard           3
# SK Raina             3
# JJ Bumrah            2
# SR Watson            2
# AB de Villiers       2
# MK Pandey            2
# M Vijay              2
# YK Pathan            2
# A Kumble             2
# HH Pandya            1
# JC Buttler           1
# RM Patidar           1
# DA Miller            1
# VR Iyer              1
# SP Narine            1
# RD Gaikwad           1
# TA Boult             1
# MP Stoinis           1
# KS Williamson        1
# RR Pant              1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# KH Pandya            1
# KV Sharma            1
# NM Coulter-Nile      1
# Washington Sundar    1
# BCJ Cutting          1
# DA Warner            1
# MC Henriques         1
# RG Sharma            1
# A Nehra              1
# V Sehwag             1
# UT Yadav             1
# Harbhajan Singh      1
# BJ Hodge             1
# MEK Hussey           1
# MS Bisla             1
# ...

# %%
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: >

# %%
(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Team1
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
data = {
    "Student_ID": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115],
    
    "Name": ["Amit", "Neha", "Rahul", "Sneha", "Vikram", "Priya", "Arjun", "Kavya", "Rohit", "Anjali",
             "Karan", "Pooja", "Varun", "Meera", "Sahil"],
    
    "Age": [20, 21, np.nan, 22, 20, np.nan, 23, 21, 22, np.nan, 24, 20, 23, np.nan, 22],
    
    "Marks": [85, np.nan, 78, 92, 88, 76, np.nan, 81, 79, 95, np.nan, 73, 84, 90, np.nan],
    
    "City": ["Ahmedabad", "Surat", "Vadodara", np.nan, "Rajkot", "Ahmedabad", "Surat",
             "Vadodara", "Rajkot", np.nan, "Ahmedabad", "Surat", np.nan, "Rajkot", "Vadodara"]
}

df = pd.DataFrame(data)

df
# Out:
#     Student_ID    Name   Age  Marks       City
# 0          101    Amit  20.0   85.0  Ahmedabad
# 1          102    Neha  21.0    NaN      Surat
# 2          103   Rahul   NaN   78.0   Vadodara
# 3          104   Sneha  22.0   92.0        NaN
# 4          105  Vikram  20.0   88.0     Rajkot
# 5          106   Priya   NaN   76.0  Ahmedabad
# 6          107   Arjun  23.0    NaN      Surat
# 7          108   Kavya  21.0   81.0   Vadodara
# 8          109   Rohit  22.0   79.0     Rajkot
# 9          110  Anjali   NaN   95.0        NaN
# 10         111   Karan  24.0    NaN  Ahmedabad
# 11         112   Pooja  20.0   73.0      Surat
# 12         113   Varun  23.0   84.0        NaN
# 13         114   Meera   NaN   90.0     Rajkot
# 14         115   Sahil  22.0    NaN   Vadodara

# %%
df.sort_values('Age',na_position='first',ascending=False)
# Out:
#     Student_ID    Name   Age  Marks       City
# 2          103   Rahul   NaN   78.0   Vadodara
# 5          106   Priya   NaN   76.0  Ahmedabad
# 9          110  Anjali   NaN   95.0        NaN
# 13         114   Meera   NaN   90.0     Rajkot
# 10         111   Karan  24.0    NaN  Ahmedabad
# 6          107   Arjun  23.0    NaN      Surat
# 12         113   Varun  23.0   84.0        NaN
# 14         115   Sahil  22.0    NaN   Vadodara
# 8          109   Rohit  22.0   79.0     Rajkot
# 3          104   Sneha  22.0   92.0        NaN
# 1          102    Neha  21.0    NaN      Surat
# 7          108   Kavya  21.0   81.0   Vadodara
# 0          101    Amit  20.0   85.0  Ahmedabad
# 4          105  Vikram  20.0   88.0     Rajkot
# 11         112   Pooja  20.0   73.0      Surat

# %%
movies = pd.read_csv('movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   str
#  1   imdb_id           1629 non-null   str
#  2   poster_path       1526 non-null   str
#  3   wiki_link         1629 non-null   str
#  4   title_y           1629 non-null   str
#  5   original_title    1629 non-null   str
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   str
#  9   genres            1629 non-null   str
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   str
#  13  summary           1629 non-null   str
#  14  tagline           557 non-null    str
#  15  actors            1624 non-null   str
#  16  wins_nominations  707 non-null    str
# ...

# %%
movies.sort_values(['title_x','year_of_release']).head(6)
# Out:
#                      title_x    imdb_id  \
# 1498      16 December (film)  tt0313844
# 1021             1920 (film)  tt1301698
# 287             1920: London  tt5638500
# 723   1920: The Evil Returns  tt2222550
# 1039        1971 (2007 film)  tt0983990
# 483     2 States (2014 film)  tt2372678
#
#                                             poster_path  \
# 1498  https://upload.wikimedia.org/wikipedia/en/thum...
# 1021  https://upload.wikimedia.org/wikipedia/en/thum...
# 287   https://upload.wikimedia.org/wikipedia/en/thum...
# 723   https://upload.wikimedia.org/wikipedia/en/e/e7...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# 483   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link             title_y  \
# 1498   https://en.wikipedia.org/wiki/16_December_(film)              16-Dec
# 1021          https://en.wikipedia.org/wiki/1920_(film)                1920
# ...

# %%
batman = pd.read_csv('batsman_runs_ipl.csv')
batman.head()
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25

# %%
batman['rank'] = batman['batsman_run'].rank(ascending=False)
batman
# Out:
#              batter  batsman_run   rank
# 0    A Ashish Reddy          280  166.5
# 1          A Badoni          161  226.0
# 2        A Chandila            4  535.0
# 3          A Chopra           53  329.0
# 4       A Choudhary           25  402.5
# ..              ...          ...    ...
# 600      Yash Dayal            0  594.0
# 601   Yashpal Singh           47  343.0
# 602     Younis Khan            3  547.5
# 603    Yuvraj Singh         2754   27.0
# 604          Z Khan          117  256.0
#
# [605 rows x 3 columns]

# %%
batman.sort_values('rank')
# Out:
#              batter  batsman_run   rank
# 569         V Kohli         6634    1.0
# 462        S Dhawan         6244    2.0
# 130       DA Warner         5883    3.0
# 430       RG Sharma         5881    4.0
# 493        SK Raina         5536    5.0
# ..              ...          ...    ...
# 570  V Pratap Singh            0  594.0
# 63     Abdur Razzak            0  594.0
# 562          U Kaul            0  594.0
# 65       Akash Deep            0  594.0
# 57           AS Roy            0  594.0
#
# [605 rows x 3 columns]

# %%
batman.set_index('batter',inplace=True)

# %%
batman
# Out:
#                 batsman_run   rank
# batter
# A Ashish Reddy          280  166.5
# A Badoni                161  226.0
# A Chandila                4  535.0
# A Chopra                 53  329.0
# A Choudhary              25  402.5
# ...                     ...    ...
# Yash Dayal                0  594.0
# Yashpal Singh            47  343.0
# Younis Khan               3  547.5
# Yuvraj Singh           2754   27.0
# Z Khan                  117  256.0
#
# [605 rows x 2 columns]

# %%
batman.reset_index(inplace=True)

# %%
batman
# Out:
#              batter  batsman_run   rank
# 0    A Ashish Reddy          280  166.5
# 1          A Badoni          161  226.0
# 2        A Chandila            4  535.0
# 3          A Chopra           53  329.0
# 4       A Choudhary           25  402.5
# ..              ...          ...    ...
# 600      Yash Dayal            0  594.0
# 601   Yashpal Singh           47  343.0
# 602     Younis Khan            3  547.5
# 603    Yuvraj Singh         2754   27.0
# 604          Z Khan          117  256.0
#
# [605 rows x 3 columns]

# %%
batman.rename(columns={'batter':'Player'},inplace=True) 
batman
# Out:
#              Player  batsman_run   rank
# 0    A Ashish Reddy          280  166.5
# 1          A Badoni          161  226.0
# 2        A Chandila            4  535.0
# 3          A Chopra           53  329.0
# 4       A Choudhary           25  402.5
# ..              ...          ...    ...
# 600      Yash Dayal            0  594.0
# 601   Yashpal Singh           47  343.0
# 602     Younis Khan            3  547.5
# 603    Yuvraj Singh         2754   27.0
# 604          Z Khan          117  256.0
#
# [605 rows x 3 columns]

# %%
batman.rename(index={0:'[]'})
# Out:
#              Player  batsman_run   rank
# []   A Ashish Reddy          280  166.5
# 1          A Badoni          161  226.0
# 2        A Chandila            4  535.0
# 3          A Chopra           53  329.0
# 4       A Choudhary           25  402.5
# ..              ...          ...    ...
# 600      Yash Dayal            0  594.0
# 601   Yashpal Singh           47  343.0
# 602     Younis Khan            3  547.5
# 603    Yuvraj Singh         2754   27.0
# 604          Z Khan          117  256.0
#
# [605 rows x 3 columns]

# %%
batman['rank'].unique().size
# Out:
# 317

# %%
#nunique   counts the unique values excluding nan
batman['rank'].nunique()
# Out:
# 317

# %%
df[df.notnull()]
# Out:
#     Student_ID    Name   Age  Marks       City
# 0          101    Amit  20.0   85.0  Ahmedabad
# 1          102    Neha  21.0    NaN      Surat
# 2          103   Rahul   NaN   78.0   Vadodara
# 3          104   Sneha  22.0   92.0        NaN
# 4          105  Vikram  20.0   88.0     Rajkot
# 5          106   Priya   NaN   76.0  Ahmedabad
# 6          107   Arjun  23.0    NaN      Surat
# 7          108   Kavya  21.0   81.0   Vadodara
# 8          109   Rohit  22.0   79.0     Rajkot
# 9          110  Anjali   NaN   95.0        NaN
# 10         111   Karan  24.0    NaN  Ahmedabad
# 11         112   Pooja  20.0   73.0      Surat
# 12         113   Varun  23.0   84.0        NaN
# 13         114   Meera   NaN   90.0     Rajkot
# 14         115   Sahil  22.0    NaN   Vadodara

# %%
df
# Out:
#     Student_ID    Name   Age  Marks       City
# 0          101    Amit  20.0   85.0  Ahmedabad
# 1          102    Neha  21.0    NaN      Surat
# 2          103   Rahul   NaN   78.0   Vadodara
# 3          104   Sneha  22.0   92.0        NaN
# 4          105  Vikram  20.0   88.0     Rajkot
# 5          106   Priya   NaN   76.0  Ahmedabad
# 6          107   Arjun  23.0    NaN      Surat
# 7          108   Kavya  21.0   81.0   Vadodara
# 8          109   Rohit  22.0   79.0     Rajkot
# 9          110  Anjali   NaN   95.0        NaN
# 10         111   Karan  24.0    NaN  Ahmedabad
# 11         112   Pooja  20.0   73.0      Surat
# 12         113   Varun  23.0   84.0        NaN
# 13         114   Meera   NaN   90.0     Rajkot
# 14         115   Sahil  22.0    NaN   Vadodara

# %%
df.dropna()
# Out:
#     Student_ID    Name   Age  Marks       City
# 0          101    Amit  20.0   85.0  Ahmedabad
# 4          105  Vikram  20.0   88.0     Rajkot
# 7          108   Kavya  21.0   81.0   Vadodara
# 8          109   Rohit  22.0   79.0     Rajkot
# 11         112   Pooja  20.0   73.0      Surat

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())
df
# Out:
#     Student_ID    Name        Age  Marks       City
# 0          101    Amit  20.000000   85.0  Ahmedabad
# 1          102    Neha  21.000000    NaN      Surat
# 2          103   Rahul  21.636364   78.0   Vadodara
# 3          104   Sneha  22.000000   92.0        NaN
# 4          105  Vikram  20.000000   88.0     Rajkot
# 5          106   Priya  21.636364   76.0  Ahmedabad
# 6          107   Arjun  23.000000    NaN      Surat
# 7          108   Kavya  21.000000   81.0   Vadodara
# 8          109   Rohit  22.000000   79.0     Rajkot
# 9          110  Anjali  21.636364   95.0        NaN
# 10         111   Karan  24.000000    NaN  Ahmedabad
# 11         112   Pooja  20.000000   73.0      Surat
# 12         113   Varun  23.000000   84.0        NaN
# 13         114   Meera  21.636364   90.0     Rajkot
# 14         115   Sahil  22.000000    NaN   Vadodara

# %%
def vkplay (players):
    return 'V Kohli' in players

# %%
ipl['AllPlayers'] = ipl['Team1Players'] + ipl['Team2Players']
ipl['VKPlay'] = ipl['AllPlayers'].apply(vkplay)
ipl.tail(30)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 920  336011      Jaipur  2008-05-09  2007/08          30
# 921  336009       Delhi  2008-05-08  2007/08          28
# 922  336010     Kolkata  2008-05-08  2007/08          29
# 923  336008      Mumbai  2008-05-07  2007/08          27
# 924  336007     Chennai  2008-05-06  2007/08          26
# 925  336006   Bangalore  2008-05-05  2007/08          25
# 926  336005      Jaipur  2008-05-04  2007/08          24
# 927  336004      Mumbai  2008-05-04  2007/08          23
# 928  336034   Bangalore  2008-05-03  2007/08          21
# 929  336003  Chandigarh  2008-05-03  2007/08          22
# 930  336001     Chennai  2008-05-02  2007/08          20
# 931  336000      Jaipur  2008-05-01  2007/08          18
# 932  335999   Hyderabad  2008-05-01  2007/08          19
# 933  335998       Delhi  2008-04-30  2007/08          17
# 934  335997     Kolkata  2008-04-29  2007/08          16
# ...

# %%
ipl[(ipl['City'] == 'Delhi') & (ipl['newCol'] == True)].drop_duplicates(subset=['City','VKPlay'])
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ... Margin method Player_of_Match  \
# 208          bat  ...   16.0    NaN        S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                         AllPlayers  \
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#     newCol VKPlay
# 208   True   True
#
# [1 rows x 23 columns]

# %%
df.drop(columns=['Age','City'])
# Out:
#     Student_ID    Name  Marks
# 0          101    Amit   85.0
# 1          102    Neha    NaN
# 2          103   Rahul   78.0
# 3          104   Sneha   92.0
# 4          105  Vikram   88.0
# 5          106   Priya   76.0
# 6          107   Arjun    NaN
# 7          108   Kavya   81.0
# 8          109   Rohit   79.0
# 9          110  Anjali   95.0
# 10         111   Karan    NaN
# 11         112   Pooja   73.0
# 12         113   Varun   84.0
# 13         114   Meera   90.0
# 14         115   Sahil    NaN

# %%
df.drop(index=[0,8])
# Out:
#     Student_ID    Name        Age  Marks       City
# 1          102    Neha  21.000000    NaN      Surat
# 2          103   Rahul  21.636364   78.0   Vadodara
# 3          104   Sneha  22.000000   92.0        NaN
# 4          105  Vikram  20.000000   88.0     Rajkot
# 5          106   Priya  21.636364   76.0  Ahmedabad
# 6          107   Arjun  23.000000    NaN      Surat
# 7          108   Kavya  21.000000   81.0   Vadodara
# 9          110  Anjali  21.636364   95.0        NaN
# 10         111   Karan  24.000000    NaN  Ahmedabad
# 11         112   Pooja  20.000000   73.0      Surat
# 12         113   Varun  23.000000   84.0        NaN
# 13         114   Meera  21.636364   90.0     Rajkot
# 14         115   Sahil  22.000000    NaN   Vadodara

# %%
df.set_index('Name')
# Out:
#         Student_ID        Age  Marks       City
# Name
# Amit           101  20.000000   85.0  Ahmedabad
# Neha           102  21.000000    NaN      Surat
# Rahul          103  21.636364   78.0   Vadodara
# Sneha          104  22.000000   92.0        NaN
# Vikram         105  20.000000   88.0     Rajkot
# Priya          106  21.636364   76.0  Ahmedabad
# Arjun          107  23.000000    NaN      Surat
# Kavya          108  21.000000   81.0   Vadodara
# Rohit          109  22.000000   79.0     Rajkot
# Anjali         110  21.636364   95.0        NaN
# Karan          111  24.000000    NaN  Ahmedabad
# Pooja          112  20.000000   73.0      Surat
# Varun          113  23.000000   84.0        NaN
# Meera          114  21.636364   90.0     Rajkot
# Sahil          115  22.000000    NaN   Vadodara
